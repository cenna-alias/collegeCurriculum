# %% [markdown]
# **Program to generate series of dates.**

# %%
import pandas as pd
sr = pd.Series(pd.date_range('2021-05-01','2021-05-12',freq='D'))
print(sr.to_string(index=False))
# Out:
# 2021-05-01
# 2021-05-02
# 2021-05-03
# 2021-05-04
# 2021-05-05
# 2021-05-06
# 2021-05-07
# 2021-05-08
# 2021-05-09
# 2021-05-10
# 2021-05-11
# 2021-05-12

# %% [markdown]
# **Program to convert index to default indexing.**

# %%
import pandas as pd
data = {'Name':['Cenna','Sana','Shaiby','Chrisa'],
        'Age':[21,22,45,13],
        'Rank':[1,2,3,4],
       }
index = ['a1','a2','a3','a4']
df = pd.DataFrame(data,index)
print(df.to_string())
df.reset_index(inplace=True,drop=True)
print(df.to_string())
# Out:
#       Name  Age  Rank
# a1   Cenna   21     1
# a2    Sana   22     2
# a3  Shaiby   45     3
# a4  Chrisa   13     4
#      Name  Age  Rank
# 0   Cenna   21     1
# 1    Sana   22     2
# 2  Shaiby   45     3
# 3  Chrisa   13     4

# %% [markdown]
# **Program to find avg salary per occupation.**

# %%
import pandas as pd
details = {
        'Name':['Cenna','Sana','Shaiby','Alias'],
        'Occupation':['Doctor','Engineer','Doctor','Engineer'],
        'Salary':[50000,55000,42000,35000],
       }
data = pd.DataFrame(details)
print(data)
occ_avg_salary = data.groupby('Occupation')['Salary'].mean()
print("Average Salary per Occupation:")
print(occ_avg_salary)
# Out:
#      Name Occupation  Salary
# 0   Cenna     Doctor   50000
# 1    Sana   Engineer   55000
# 2  Shaiby     Doctor   42000
# 3   Alias   Engineer   35000
# Average Salary per Occupation:
# Occupation
# Doctor      46000.0
# Engineer    45000.0
# Name: Salary, dtype: float64
